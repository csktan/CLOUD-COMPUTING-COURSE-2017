# %%
import tweepy
from tweepy import OAuthHandler
 
consumer_key = 'your key'
consumer_secret = 'customer secrete key'
access_token = 'access key'
access_secret = 'your secrete key'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
user = api.me()
 
print('Name: ' + user.name)
print('Location: ' + user.location)
print('Friends: ' + str(user.followers_count))
print('Created: ' + str(user.created_at))
print('Description: ' + str(user.description))
# Out:
# Name: Chetan kc
# Location: nepal
# Friends: 436
# Created: 2011-05-30 17:10:16
# Description: Complicated!!!

# %%
for status in tweepy.Cursor(api.home_timeline).items(1):
    print(status.text)
# Out:
# why tweepy is not workling???? 😡😡

# %%
import json

for status in tweepy.Cursor(api.home_timeline).items(1):
    print(json.dumps(status._json, indent=2))
# Out:
# {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @DeAndresPage: Darling, it's all in your head.",
#   "is_quote_status": false,
#   "in_reply_to_status_id": null,
#   "id": 859792347244011521,
#   "favorite_count": 0,
#   "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#     "symbols": [],
#     "user_mentions": [
#       {
#         "id": 4871521460,
#         "indices": [
#           3,
#           16
#         ],
#         "id_str": "4871521460",
#         "screen_name": "DeAndresPage",
#         "name": "DeAndre"
#       }
#     ],
#     "hashtags": [],
#     "urls": []
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 649,
#   "id_str": "859792347244011521",
#   "favorited": false,
#   "retweeted_status": {
#     "contributors": null,
#     "truncated": false,
# ...

# %%
for friend in tweepy.Cursor(api.friends).items(1):
    print(json.dumps(friend._json, indent=2))
# Out:
# {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": false,
#   "live_following": false,
#   "default_profile_image": false,
#   "id": 842056138338275330,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "translator_type": "none",
#   "verified": false,
#   "blocked_by": false,
#   "profile_text_color": "000000",
#   "muting": false,
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/847863901932978180/2L1QbKaf_normal.jpg",
#   "profile_sidebar_fill_color": "000000",
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "followers_count": 447,
#   "profile_sidebar_border_color": "000000",
#   "id_str": "842056138338275330",
#   "profile_background_color": "000000",
#   "listed_count": 2,
#   "status": {
#     "contributors": null,
#     "truncated": false,
# ...

# %%
for tweet in tweepy.Cursor(api.user_timeline).items(1):
    print(json.dumps(tweet._json, indent=2))
# Out:
# {
#   "contributors": null,
#   "truncated": false,
#   "text": "why tweepy is not workling???? \ud83d\ude21\ud83d\ude21",
#   "is_quote_status": false,
#   "in_reply_to_status_id": null,
#   "id": 859791127330918400,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [],
#     "urls": []
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "859791127330918400",
#   "favorited": false,
#   "user": {
#     "follow_request_sent": false,
#     "has_extended_profile": true,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 307995792,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#     "verified": false,
#     "translator_type": "none",
# ...

# %% [markdown]
# # print lastest tweet from my home

# %%
for status in tweepy.Cursor(api.home_timeline).items(2):
    # Process a single status
    print(status.text)
# Out:
# 💥BTTS &amp; WIN TREBLE TIPS!💥
#
# On this @ 102/1 tonight ▶️ https://t.co/b63gwO1oJr
#
# #TipsFT 💷⚽📺🏆 https://t.co/X38Y7EoZXX
# Can't wait for the next bank holiday weekend for a getaway? https://t.co/fyJGPsOche https://t.co/BDLfPJmif8

# %%
for friend in tweepy.Cursor(api.friends).items(1):
    print(friend._json)
# Out:
# {u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': False, u'live_following': False, u'default_profile_image': False, u'id': 842056138338275330, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'translator_type': u'none', u'verified': False, u'blocked_by': False, u'profile_text_color': u'000000', u'muting': False, u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/847863901932978180/2L1QbKaf_normal.jpg', u'profile_sidebar_fill_color': u'000000', u'entities': {u'description': {u'urls': []}}, u'followers_count': 447, u'profile_sidebar_border_color': u'000000', u'id_str': u'842056138338275330', u'profile_background_color': u'000000', u'listed_count': 2, u'status': {u'contributors': None, u'truncated': False, u'text': u'Las marchas y la caja de cambios en pocas palabras.\nhttps://t.co/XrBB086Sqq https://t.co/Keo4meKGDH', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id
# ...

# %%
for tweet in tweepy.Cursor(api.user_timeline).items(5):
    tweetJSON = tweet._json
    print tweetJSON["user"]["name"], "at",tweetJSON["created_at"],tweetJSON["favorite_count"],tweetJSON["retweet_count"],":", tweetJSON["text"]
# Out:
#  Chetan kc at Wed May 03 15:25:53 +0000 2017 1 0 : why tweepy is not workling???? 😡😡
# Chetan kc at Wed May 03 15:24:17 +0000 2017 0 0 : https://t.co/gdf7hC82iz
# Chetan kc at Fri Apr 28 06:33:48 +0000 2017 0 0 : Number crunching for the past week - 2 new followers and NO unfollowers. Stats via https://t.co/IxEFfQDqTv
# Chetan kc at Mon Apr 24 10:19:39 +0000 2017 2 0 : "Your greatest dreams are all on the other side of the wall of fear and caution." —Unknown via @momentumdash
# Chetan kc at Fri Apr 14 06:33:42 +0000 2017 0 0 : Stats for the week have arrived. 1 new follower and NO unfollowers :) via https://t.co/IxEFfQV1L3.

# %%
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens
 
tweet = 'RT @csktan: just an example! https://example.com'
print(preprocess(tweet))
# Out:
# ['RT', '@csktan', ':', 'just', 'an', 'example', '!', 'https://example.com']

# %%
  tweet = "Hello, world!"
  status = api.update_status(status=tweet)

# %%
twt = api.search(q="Hello World!")
print (twt)
# Out:
# [Status(contributors=None, truncated=False, text=u'Hello Twitter World! #myfirsttweet #events #luxury #eventprofs #london #incentives #party #corporateevents https://t.co/8R8GZKudYF', is_quote_status=False, in_reply_to_status_id=None, id=859806326351941633, favorite_count=0, _api=<tweepy.api.API object at 0x7f3b2b182dd0>, author=User(follow_request_sent=False, has_extended_profile=False, profile_use_background_image=False, _json={u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': False, u'default_profile_image': False, u'id': 859797180126830592, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'translator_type': u'none', u'profile_text_color': u'000000', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/859798120263274496/lguyiXrh_normal.jpg', u'profile_sidebar_fill_color': u'000000', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/GBDh6CTtj4', u'ind
# ...
